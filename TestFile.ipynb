# %%
import pandas as pd
import numpy as np
import datetime 
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel(r"C:\Users\Swarupa\Downloads\Book1.xlsx", index_col=0, parse_dates=True)
df1 = df[(df.index >="2020-01-01") & (df.index <="2025-08-19")].copy()
df1.index.name = 'date'
df1.head()
# Out:
#             Adanit ent  Adani Port  Apollo Hosp  Asian Paint  Axis bank  \
# date
# 2025-08-19      2388.4      1369.4       7823.5       2579.4     1083.2
# 2025-08-18      2333.6      1327.2       7822.5       2587.4     1082.6
# 2025-08-14      2281.6      1300.3       7821.5       2528.7     1068.2
# 2025-08-13      2280.1      1319.6       7808.5       2500.2     1066.0
# 2025-08-12      2288.2      1330.5       7236.5       2478.3     1070.0
#
#             Bajaj Auto  Bajaj fins  Bajaj Finance     BEL  Bharti Airtel  ...  \
# date                                                                      ...
# 2025-08-19      8795.5      1972.2         902.30  380.05         1909.7  ...
# 2025-08-18      8588.5      1993.5         905.20  382.50         1892.3  ...
# 2025-08-14      8213.5      1925.1         861.45  384.90         1873.8  ...
# 2025-08-13      8248.5      1914.4         860.00  388.85         1867.4  ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1401 entries, 2025-08-19 to 2020-01-01
# Data columns (total 50 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Adanit ent     1401 non-null   float64
#  1   Adani Port     1401 non-null   float64
#  2   Apollo Hosp    1401 non-null   float64
#  3   Asian Paint    1401 non-null   float64
#  4   Axis bank      1401 non-null   float64
#  5   Bajaj Auto     1401 non-null   float64
#  6   Bajaj fins     1401 non-null   float64
#  7   Bajaj Finance  1401 non-null   float64
#  8   BEL            1401 non-null   float64
#  9   Bharti Airtel  1401 non-null   float64
#  10  Cipla          1401 non-null   float64
#  11  Coal india     1401 non-null   float64
#  12  Dr reddy       1401 non-null   float64
#  13  Eicher Mot     1401 non-null   float64
#  14  Eternal        1012 non-null   float64
#  15  Grasim         1401 non-null   float64
# ...

# %%
print("Shape:", df1.shape)
print("Index:", df1.index[:5])
print("Columns:", df1.columns[:5])
# Out:
# Shape: (1401, 50)
# Index: DatetimeIndex(['2025-08-19', '2025-08-18', '2025-08-14', '2025-08-13',
#                '2025-08-12'],
#               dtype='datetime64[ns]', name='date', freq=None)
# Columns: Index(['Adanit ent', 'Adani Port', 'Apollo Hosp', 'Asian Paint', 'Axis bank'], dtype='object')

# %%
df = pd.read_excel(r"C:\Users\Swarupa\Downloads\Book1.xlsx",
                   index_col=0,
                   parse_dates=True,
                   engine='openpyxl')

# %%
series = df1['TCS']      # choose which company

plt.figure(figsize=(10,5))
plt.plot(series.index, series.values)
plt.title("TCS Closing Price (2020 - 2025)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,10))
for col in df1.columns:
    plt.plot(df1.index, df1[col], linewidth=0.8)

plt.title("NIFTY50 — Closing Prices for All Companies (2020–2025)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
series = df1['Wipro']      # choose which company

plt.figure(figsize=(10,5))
plt.plot(series.index, series.values)
plt.title("Wipro Closing Price (2020 - 2025)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(True)
plt.show()
